# %% [markdown]
# # 6.3 Geographical Visualizations with Python

# %% [markdown]
# ## Contents
# 01. Import Libraries & Data
# 02. Data Wrangling
# 03. Plotting a Choropleth with Geoplot
# 04. Insights from the Analysis

# %% [markdown]
# ## 01. Import Libraries & Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import folium
import json

# %%
# Import ".json" file for the U.S. 
country_geo = r'C:/Users/Dell/Documents/IBM Watson Marketing Customer Value Data/02. Data/Original Data/us-states.json'

# %%
# Importing Data
# create path
path = r'C:\Users\Dell\Documents\IBM Watson Marketing Customer Value Data'

# %%
# import customer_value dataset
df = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'customer_value_new.pkl'))

# %% [markdown]
# ## 02. Data Wrangling

# %%
df.columns
# Out:
# Index(['Customer Id', 'State', 'Customer Lifetime Value', 'Response',
#        'Coverage', 'Policy Expiry Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
# Dropping unwanted columns
# Droping unwanted columns
df =df.drop(columns=['Location Code'])

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# Customer Id                      0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Policy Expiry Date               0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
# Finding duplicates
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Customer Id, State, Customer Lifetime Value, Response, Coverage, Policy Expiry Date, EmploymentStatus, Gender, Income, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# # 03. Plotting a Choropleth with Geoplot

# %%
# Creat a subset
data_to_plot =df[[ 'State', 'Customer Lifetime Value']]

# %%
data_to_plot
# Out:
#            State  Customer Lifetime Value
# 0     Washington              2763.519279
# 1        Arizona              6979.535903
# 2         Nevada             12887.431650
# 3     California              7645.861827
# 4     Washington              2813.692575
# ...          ...                      ...
# 9129  California             23405.987980
# 9130  California              3096.511217
# 9131  California              8163.890428
# 9132  California              7524.442436
# 9133  California              2611.836866
#
# [9134 rows x 2 columns]

# %%
map = folium.Map(location = [40, -95], zoom_start = 4)

folium.Choropleth(
    geo_data = country_geo, 
    data = data_to_plot,
    columns = ['State', 'Customer Lifetime Value'],
    key_on = 'feature.properties.name',
    fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "Customer Lifetime Value").add_to(map)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_384e73f82e9e30a50a47ff0dfc172150 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_384e73f82e9e30a50a47ff0dfc172150&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_384e73f82e9e30a50a47ff0dfc172150 = L.map(
#                 &quot;map_384e73f82e9e30a50a47ff0dfc172150&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b92655f8a8dd7d292e3144b9cd13a2f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b92655f8a8dd7d292e3144b9cd13a2f4.addTo(map_384e73f82e9e30a50a47ff0dfc172150);
#
#
#             var choropleth_b588f81b364141ae402415f5944a00c1 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_86b7ee132ac4dfcb9b0d7e0b3242b7d9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OH&quot;: case &quot;OK&quot;: case &quot;PA&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WI&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffd4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;NV&quot;: case &quot;OR&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#993404&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fec44f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_86b7ee132ac4dfcb9b0d7e0b3242b7d9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_86b7ee132ac4dfcb9b0d7e0b3242b7d9 = L.geoJson(null, {
#                 onEachFeature: geo_json_86b7ee132ac4dfcb9b0d7e0b3242b7d9_onEachFeature,
#
#                 style: geo_json_86b7ee132ac4dfcb9b0d7e0b3242b7d9_styler,
#         });
#
#         function geo_json_86b7ee132ac4dfcb9b0d7e0b3242b7d9_add (data) {
#             geo_json_86b7ee132ac4dfcb9b0d7e0b3242b7d9
#                 .addData(data);
#         }
#             geo_json_86b7ee132ac4dfcb9b0d7e0b3242b7d9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469]

# %% [markdown]
# ####
# The choropleth map does not encompass the complete datase here(.When CLV values have a wide range, it means that some values might be much larger or smaller than others. This can lead to challenges in visualization because the differences in these values might not be visually apparen)t.So I have chosen a normalization method here.Normalization helps by scaling down these values to a common scale, making them easier to compare and visualize. Min-Max normalization is one such technique where you transform your data so that the minimum value becomes 0 and the maximum value becomes 1, with all other values scaled proportionally in between.

# %%
# Applying the normalization method
# Import the MinMaxScaler from sklearn
from sklearn.preprocessing import MinMaxScaler

# Normalize the CLV values
scaler = MinMaxScaler()
data_to_plot['Customer Lifetime Value Normalized'] = scaler.fit_transform(data_to_plot[['Customer Lifetime Value']])
# Create the choropleth map with normalized CLV values
map = folium.Map(location=[40, -95], zoom_start=4)

folium.Choropleth(
    geo_data=country_geo,
    data=data_to_plot,
    columns=['State', 'Customer Lifetime Value Normalized'],  # Use the normalized CLV values
    key_on='feature.properties.name',
    fill_color='YlOrBr',
    fill_opacity=0.6,
    line_opacity=0.1,
    legend_name="Normalized Customer Lifetime Value"  # Update legend name to reflect normalization
).add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20224\2146237030.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_plot['Customer Lifetime Value Normalized'] = scaler.fit_transform(data_to_plot[['Customer Lifetime Value']])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbce2cb8bdd2e9023c040d80020f8d82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbce2cb8bdd2e9023c040d80020f8d82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbce2cb8bdd2e9023c040d80020f8d82 = L.map(
#                 &quot;map_bbce2cb8bdd2e9023c040d80020f8d82&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e48047a97a9ee0446e448697f8bb560e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e48047a97a9ee0446e448697f8bb560e.addTo(map_bbce2cb8bdd2e9023c040d80020f8d82);
#
#
#             var choropleth_a7a2c52d4dad537216fa241023555d94 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_8b16b3c1f4a8377bb6652107b76e5678_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OH&quot;: case &quot;OK&quot;: case &quot;PA&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WI&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffd4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;NV&quot;: case &quot;OR&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#993404&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fec44f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_8b16b3c1f4a8377bb6652107b76e5678_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8b16b3c1f4a8377bb6652107b76e5678 = L.geoJson(null, {
#                 onEachFeature: geo_json_8b16b3c1f4a8377bb6652107b76e5678_onEachFeature,
#
#                 style: geo_json_8b16b3c1f4a8377bb6652107b76e5678_styler,
#         });
#
#         function geo_json_8b16b3c1f4a8377bb6652107b76e5678_add (data) {
#             geo_json_8b16b3c1f4a8377bb6652107b76e5678
#                 .addData(data);
#         }
#             geo_json_8b16b3c1f4a8377bb6652107b76e5678_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469]

# %%
map.save('plot_data1.html')

# %% [markdown]
# #### The plot illustrates the distribution of Customer Lifetime Value (CLV) across the United States. Nevada and Oregon demonstrate the highest CLV value customers, with Washington following closely. Conversely, California and Arizona exhibit the lowest values.

# %%
# filtering the DataFrame to include only rows where 'Response' is 'Yes
df1= df[df['Response'] == 'Yes']

# %%
# Creat a subset
data_to_plot1 =df1[[ 'State', 'Customer Lifetime Value']]

# %%
data_to_plot1
# Out:
#            State  Customer Lifetime Value
# 5         Oregon              8256.297800
# 6         Oregon              5380.898636
# 8         Oregon             24127.504020
# 13       Arizona              8819.018934
# 22       Arizona             24127.504020
# ...          ...                      ...
# 9110  California             34611.378960
# 9119  California              5479.555081
# 9122  California             25464.820590
# 9123  California              5678.050167
# 9130  California              3096.511217
#
# [1308 rows x 2 columns]

# %%
map = folium.Map(location = [40, -95], zoom_start = 4)

folium.Choropleth(
    geo_data = country_geo, 
    data = data_to_plot1,
    columns = ['State', 'Customer Lifetime Value'],
    key_on = 'feature.properties.name',
    fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "Customer Lifetime Value").add_to(map)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92cd2101a89a2ff5f953679e58955c69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92cd2101a89a2ff5f953679e58955c69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92cd2101a89a2ff5f953679e58955c69 = L.map(
#                 &quot;map_92cd2101a89a2ff5f953679e58955c69&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b3e8f9db551d5b6e01f7b31eec6a553 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6b3e8f9db551d5b6e01f7b31eec6a553.addTo(map_92cd2101a89a2ff5f953679e58955c69);
#
#
#             var choropleth_eaa3bbeafac6b77029127b08c8885517 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_ee2640f10829be0862cf7608b51d9fc6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OH&quot;: case &quot;OK&quot;: case &quot;PA&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WI&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee391&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;OR&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffd4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;NV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#993404&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d95f0e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ee2640f10829be0862cf7608b51d9fc6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ee2640f10829be0862cf7608b51d9fc6 = L.geoJson(null, {
#                 onEachFeature: geo_json_ee2640f10829be0862cf7608b51d9fc6_onEachFeature,
#
#                 style: geo_json_ee2640f10829be0862cf7608b51d9fc6_styler,
#         });
#
#         function geo_json_ee2640f10829be0862cf7608b51d9fc6_add (data) {
#             geo_json_ee2640f10829be0862cf7608b51d9fc6
#                 .addData(data);
#         }
#             geo_json_ee2640f10829be0862cf7608b51d9fc6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&

# %%
# Applying the normalization method
# Import the MinMaxScaler from sklearn
from sklearn.preprocessing import MinMaxScaler

# Normalize the CLV values
scaler = MinMaxScaler()
data_to_plot1['Customer Lifetime Value Normalized'] = scaler.fit_transform(data_to_plot1[['Customer Lifetime Value']])
# Create the choropleth map with normalized CLV values
map = folium.Map(location=[40, -95], zoom_start=4)

folium.Choropleth(
    geo_data=country_geo,
    data=data_to_plot1,
    columns=['State', 'Customer Lifetime Value Normalized'],  # Use the normalized CLV values
    key_on='feature.properties.name',
    fill_color='YlOrBr',
    fill_opacity=0.6,
    line_opacity=0.1,
    legend_name="Normalized Customer Lifetime Value"  # Update legend name to reflect normalization
).add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20224\263065570.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_plot1['Customer Lifetime Value Normalized'] = scaler.fit_transform(data_to_plot1[['Customer Lifetime Value']])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc33e638b867bbd455e43621017bc2e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc33e638b867bbd455e43621017bc2e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc33e638b867bbd455e43621017bc2e2 = L.map(
#                 &quot;map_dc33e638b867bbd455e43621017bc2e2&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_148fcc96a2740c15eb7a64c8d50ca02a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_148fcc96a2740c15eb7a64c8d50ca02a.addTo(map_dc33e638b867bbd455e43621017bc2e2);
#
#
#             var choropleth_685ab7da70d23647c30ab05862f809ff = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_e8565c45275990e0c01b26d998e9033b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OH&quot;: case &quot;OK&quot;: case &quot;PA&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WI&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee391&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;OR&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffd4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;NV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#993404&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d95f0e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e8565c45275990e0c01b26d998e9033b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e8565c45275990e0c01b26d998e9033b = L.geoJson(null, {
#                 onEachFeature: geo_json_e8565c45275990e0c01b26d998e9033b_onEachFeature,
#
#                 style: geo_json_e8565c45275990e0c01b26d998e9033b_styler,
#         });
#
#         function geo_json_e8565c45275990e0c01b26d998e9033b_add (data) {
#             geo_json_e8565c45275990e0c01b26d998e9033b
#                 .addData(data);
#         }
#             geo_json_e8565c45275990e0c01b26d998e9033b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&

# %%
map.save('plot_data2.html')

# %% [markdown]
# #### The graph displays the distribution of Customer Lifetime Value (CLV) based on positive responses to policy renewal throughout the United States. Nevada and Washington stand out for having the highest CLV among customers who have positively responded to policy renewals, with Arizona following closely. Conversely, California and Oregon have the lowest CLV among such customers.

# %%
# Group by demographic or policy type segment
grouped = df.groupby(['Gender', 'Policy Type'])

# %%
grouped['Customer Lifetime Value'].describe()
# Out:
#                         count         mean          std          min  \
# Gender Policy Type
# F      Corporate Auto  1005.0  7942.296743  6527.703049  2004.350666
#        Personal Auto   3454.0  8132.580041  7107.349236  1898.683686
#        Special Auto     199.0  8251.427881  6394.589754  2004.350666
# M      Corporate Auto   963.0  7680.944727  6141.798341  2129.063055
#        Personal Auto   3334.0  7918.359992  6908.708911  1898.007675
#        Special Auto     179.0  8975.365788  7542.595671  2191.133237
#
#                                25%          50%           75%          max
# Gender Policy Type
# F      Corporate Auto  3808.122147  5678.050167   9031.214859  46770.94705
#        Personal Auto   4048.895576  5730.633840   9031.214859  73225.95652
#        Special Auto    4373.264920  6503.397049   9417.200225  38496.94701
# M      Corporate Auto  3968.079029  5793.157728   8804.898950  61134.68307
#        Personal Auto   3963.396956  5814.145650   8851.377572  83325.38119
#        Special Auto    4290.592156  6236.018595  10871.288965  44795.46942

# %% [markdown]
# #### The highest mean customer lifetime value is associated with the "Special Auto" policy type.The gender female generally exhibit higher mean values compared to males across all policy types.

# %%
# filtering the DataFrame to include only rows where 'Policy Type' is 'Special Auto'
df2 = df[df['Policy Type'] == 'Special Auto']

# %%
# Creat a subset
data_to_plot2 =df2[[ 'State', 'Customer Lifetime Value']]

# %%
data_to_plot2
# Out:
#            State  Customer Lifetime Value
# 9         Oregon              7388.178085
# 44    Washington              2443.665166
# 52        Nevada              7983.431709
# 56    California              7619.515800
# 127      Arizona              3837.451863
# ...          ...                      ...
# 8347  California              9718.463569
# 8362      Oregon              2889.087654
# 8399  Washington             17684.654560
# 8412      Oregon              2548.509175
# 8423  California              4599.759229
#
# [378 rows x 2 columns]

# %%
map = folium.Map(location = [40, -95], zoom_start = 4)

folium.Choropleth(
    geo_data = country_geo, 
    data = data_to_plot2,
    columns = ['State', 'Customer Lifetime Value'],
    key_on = 'feature.properties.name',
    fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "Customer Lifetime Value").add_to(map)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_819f64f96e6841104a5edff7dc86f239 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_819f64f96e6841104a5edff7dc86f239&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_819f64f96e6841104a5edff7dc86f239 = L.map(
#                 &quot;map_819f64f96e6841104a5edff7dc86f239&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c809e5271d49cb5aa34a95f16e3a4e41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c809e5271d49cb5aa34a95f16e3a4e41.addTo(map_819f64f96e6841104a5edff7dc86f239);
#
#
#             var choropleth_5a387a34af245db20b845ed026e9b055 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_b61119da4a247be0aff1c500fa9985ba_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OH&quot;: case &quot;OK&quot;: case &quot;PA&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WI&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CA&quot;: case &quot;OR&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffd4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;NV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fe9929&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#993404&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b61119da4a247be0aff1c500fa9985ba_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b61119da4a247be0aff1c500fa9985ba = L.geoJson(null, {
#                 onEachFeature: geo_json_b61119da4a247be0aff1c500fa9985ba_onEachFeature,
#
#                 style: geo_json_b61119da4a247be0aff1c500fa9985ba_styler,
#         });
#
#         function geo_json_b61119da4a247be0aff1c500fa9985ba_add (data) {
#             geo_json_b61119da4a247be0aff1c500fa9985ba
#                 .addData(data);
#         }
#             geo_json_b61119da4a247be0aff1c500fa9985ba_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469]

# %%
# Applying the normalization method
# Import the MinMaxScaler from sklearn
from sklearn.preprocessing import MinMaxScaler

# Normalize the CLV values
scaler = MinMaxScaler()
data_to_plot2['Customer Lifetime Value Normalized'] = scaler.fit_transform(data_to_plot2[['Customer Lifetime Value']])
# Create the choropleth map with normalized CLV values
map = folium.Map(location=[40, -95], zoom_start=4)

folium.Choropleth(
    geo_data=country_geo,
    data=data_to_plot2,
    columns=['State', 'Customer Lifetime Value Normalized'],  # Use the normalized CLV values
    key_on='feature.properties.name',
    fill_color='YlOrBr',
    fill_opacity=0.6,
    line_opacity=0.1,
    legend_name="Normalized Customer Lifetime Value"  # Update legend name to reflect normalization
).add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20224\1606425407.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_plot2['Customer Lifetime Value Normalized'] = scaler.fit_transform(data_to_plot2[['Customer Lifetime Value']])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b01eadec0ebc3a03543df2f3a0ae1b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b01eadec0ebc3a03543df2f3a0ae1b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b01eadec0ebc3a03543df2f3a0ae1b7 = L.map(
#                 &quot;map_8b01eadec0ebc3a03543df2f3a0ae1b7&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36d88cd9077f56816ae355beb26fb869 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_36d88cd9077f56816ae355beb26fb869.addTo(map_8b01eadec0ebc3a03543df2f3a0ae1b7);
#
#
#             var choropleth_ff156383e759619f679a52d231ba4aba = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_8f8a83bc149dddf1c7fbd7ddab48f741_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OH&quot;: case &quot;OK&quot;: case &quot;PA&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WI&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CA&quot;: case &quot;OR&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffd4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;NV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fe9929&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#993404&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_8f8a83bc149dddf1c7fbd7ddab48f741_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8f8a83bc149dddf1c7fbd7ddab48f741 = L.geoJson(null, {
#                 onEachFeature: geo_json_8f8a83bc149dddf1c7fbd7ddab48f741_onEachFeature,
#
#                 style: geo_json_8f8a83bc149dddf1c7fbd7ddab48f741_styler,
#         });
#
#         function geo_json_8f8a83bc149dddf1c7fbd7ddab48f741_add (data) {
#             geo_json_8f8a83bc149dddf1c7fbd7ddab48f741
#                 .addData(data);
#         }
#             geo_json_8f8a83bc149dddf1c7fbd7ddab48f741_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469]

# %%
map.save('plot_data3.html')

# %% [markdown]
# #### The graph illustrates the distribution of Customer Lifetime Value (CLV) concerning the "Special Auto" policy type, known for attracting customers with the highest CLV. Nevada and Washington lead with the highest CLV customers. Conversely, Oregon,California and Arizona exhibit the lowest CLV values for customers under this policy type.

# %% [markdown]
# ## 04. Insights from the Analysis

# %% [markdown]
# ####
# CLV varies across the U.S., with Nevada having high CLV customers and California lower. "Special Auto" policies attract high CLV customers, especially in Nevada and Washington. Positive policy renewals are linked to higher CLV, notably in Nevada and Washington. Businesses can target high CLV states like Nevada and Washington for marketing, adjusting strategies in lower CLV states like California and Oregon to boost profitability.
